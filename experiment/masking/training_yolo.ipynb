# %%
# 1. YOLOv11 설치 (최신 버전)
# !pip install ultralytics roboflow
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# 2. Roboflow에서 데이터셋 다운로드 (모델 말고 '데이터'만 받음 -> 무료)
from roboflow import Roboflow
rf = Roboflow(api_key="W5jHnLnencpZhLjEhEGr")
project = rf.workspace("snap2report").project("s2r-masking")
dataset = project.version(3).download("yolov11")

# 3. 내 데이터로 YOLOv11 Nano 학습 시작 (코랩 GPU 사용)
# epochs=50: 50번 반복 학습 (사진이 적으니 금방 끝남)
from ultralytics import YOLO

# COCO로 미리 학습된 yolo11n.pt를 가져와서 내 데이터로 튜닝
model = YOLO('yolo11n.pt') 

print("학습을 시작합니다... (약 3~5분 소요)")
results = model.train(data=f"{dataset.location}/data.yaml", epochs=50, imgsz=640, plots=True)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov11 in progress : 85.0%
# Version export complete for yolov11 format
# ...
# Extracting Dataset Version Zip to s2r-masking-3 in yolov11:: 100%|██████████| 142/142 [00:00<00:00, 6521.31it/s]
# ...
# 학습을 시작합니다... (약 3~5분 소요)
# Ultralytics 8.3.236 🚀 Python-3.12.5 torch-2.9.1 CPU (Apple M3 Pro)
# ...
